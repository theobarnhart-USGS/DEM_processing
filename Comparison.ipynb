# %%
import rasterio as rs

# %%
arcfl = './data/test_accum_arc.tif'
taufl = './data/test_data_tarb_d8accum.tif'
richfl = './data/test_data_rd_accumd8.tiff'

# %%
def read_rast(fl):
    with rs.open(fl) as ds:
        dat = ds.read(1)
        
    return dat

# %%
arc = read_rast(arcfl)
tau = read_rast(taufl)
rich = read_rast(richfl)

# %%
Dtau = arc - tau
Drich = arc - rich

# %%
cmap = plt.cm.Blues
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

ax1.imshow(arc,cmap=cmap)
ax2.imshow(tau,cmap=cmap)
ax3.imshow(rich,cmap=cmap)

# %%
np.sum(arc)
# Out:
# 1.889913e+10

# %%
np.sum(tau)
# Out:
# 2.5119148e+09

# %%
np.sum(rich)
# Out:
# 1.052815e+08
